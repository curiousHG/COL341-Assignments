# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LassoLars
data = pd.read_csv('data/train_large.csv')

# %%
data.columns
# Out:
# Index(['Unnamed: 0', 'Health Service Area', 'Hospital County',
#        'Operating Certificate Number', 'Facility Id', 'Facility Name',
#        'Age Group', 'Zip Code - 3 digits', 'Gender', 'Race', 'Ethnicity',
#        'Length of Stay', 'Type of Admission', 'Patient Disposition',
#        'CCS Diagnosis Code', 'CCS Diagnosis Description', 'CCS Procedure Code',
#        'CCS Procedure Description', 'APR DRG Code', 'APR DRG Description',
#        'APR MDC Code', 'APR MDC Description', 'APR Severity of Illness Code',
#        'APR Severity of Illness Description', 'APR Risk of Mortality',
#        'APR Medical Surgical Description', 'Payment Typology 1',
#        'Payment Typology 2', 'Payment Typology 3', 'Birth Weight',
#        'Emergency Department Indicator', 'Total Costs'],
#       dtype='object')

# %%
to_drop = [  
        "Facility Id",
        "CCS Procedure Code",
        "CCS Diagnosis Code",
        "APR DRG Code",
        "APR MDC Code",
        "APR Severity of Illness Code",
        "Unnamed: 0"
]

# %%
data.drop(to_drop,axis=1,inplace=True)
X = data.drop(["Total Costs"],axis=1)
y = data['Total Costs']

# %%
poly = PolynomialFeatures(degree=2,include_bias=False)
X_poly = poly.fit_transform(X)

# %%
sampling_set = np.random.choice(X.shape[0],size=int(X.shape[0]*0.3),replace=False)
lars_X = X_poly[sampling_set]
lars_y = y[sampling_set]
model = LassoLars(alpha=0.1).fit(lars_X,lars_y)

# %%
active_X = X_poly[:,model.active_]

# %%
from scipy.stats import chi2_contingency
def cramers_V(var1,var2) :
  crosstab =np.array(pd.crosstab(var1,var2, rownames=None, colnames=None)) # Cross table building
  stat = chi2_contingency(crosstab)[0] # Keeping of the test statistic of the Chi2 test
  obs = np.sum(crosstab) # Number of observations
  mini = min(crosstab.shape)-1 # Take the minimum value between the columns and the rows of the cross table
  return (stat/(obs*mini))

# %%
to_comp = ['Health Service Area', 'Hospital County','Facility Id', 'Facility Name',
       'Age Group', 'Zip Code - 3 digits', 'Gender', 'Race', 'Ethnicity','Type of Admission', 'Patient Disposition',
       'CCS Diagnosis Code', 'CCS Diagnosis Description', 'CCS Procedure Code',
       'CCS Procedure Description', 'APR DRG Code', 'APR DRG Description',
       'APR MDC Code', 'APR MDC Description', 'APR Severity of Illness Code',
       'APR Severity of Illness Description', 'APR Risk of Mortality',
       'APR Medical Surgical Description', 'Payment Typology 1',
       'Payment Typology 2', 'Payment Typology 3',
       'Emergency Department Indicator']
data_encoded = data.get(to_comp)
rows= []
for var1 in data_encoded:
  col = []
  for var2 in data_encoded :
    cramers =cramers_V(data_encoded[var1], data_encoded[var2]) # Cramer's V test
    col.append(cramers) # Keeping of the rounded value of the Cramer's V  
  rows.append(col)
cramers_results = np.array(rows)
df = pd.DataFrame(cramers_results, columns = data_encoded.columns, index =data_encoded.columns)
df
# Out:
#                                      Health Service Area  Hospital County  \
# Health Service Area                             1.000000         1.000000
# Hospital County                                 1.000000         1.000000
# Facility Id                                     1.000000         1.000000
# Facility Name                                   1.000000         1.000000
# Age Group                                       0.003624         0.006264
# Zip Code - 3 digits                             0.811583         0.324564
# Gender                                          0.000062         0.000451
# Race                                            0.060777         0.105596
# Ethnicity                                       0.021173         0.051130
# Type of Admission                               0.003078         0.015728
# Patient Disposition                             0.002846         0.007700
# CCS Diagnosis Code                              0.007919         0.003362
# CCS Diagnosis Description                       0.007919         0.003362
# CCS Procedure Code                              0.019479         0.005597
# CCS Procedure Description                       0.019479         0.005597
# APR DRG Code                                    0.009133         0.003882
# APR DRG Description                             0.009133         0.003882
# APR MDC Code                                    0.002875         0.003031
# APR MDC Description                             0.002875         0.003031
# APR Severity of Illness Code                    0.001004         0.003008
# APR Severity of Illness Description             0.001004         0.003008
# APR Risk of Mortality                           0.001965         0.003230
# APR Medical Surgical Description                0.002636         0.024265
# Payment Typology 1                              0.010555         0.026145
# Payment Typology 2                              0.019451         0.041796
# Payment Typology 3                              0.012117         0.033962
# Emergency Department Indicator                  0.004783         0.044430
#
#                                      Facility Id  Facility Name  Age Group  \
# Health Service Area                     1.000000       1.000000   0.003624
# Hospital County                         1.000000       1.000000   0.006264
# Facility Id                             1.000000       1.000000   0.044879
# Facility Name                           1.000000       1.000000   0.044922
# Age Group                               0.044879       0.044922   1.000000
# Zip Code - 3 digits                     0.387115       0.387116   0.005034
# Gender                                  0.006372       0.006387   0.014630
# Race                                    0.230153       0.230155   0.014745
# Ethnicity                               0.163295       0.163296   0.006575
# Type of Admission                       0.068559       0.068625   0.163212
# Patient Disposition                     0.021459       0.021462   0.067582
# CCS Diagnosis Code                      0.006834       0.006775   0.308290
# CCS Diagnosis Description               0.006834       0.006775   0.308290
# CCS Procedure Code                      0.008353       0.008281   0.196578
# CCS Procedure Description               0.008353       0.008281   0.196578
# APR DRG Code                            0.008125       0.008055   0.305763
# APR DRG Description                     0.008125       0.008055   0.305763
# APR MDC Code                            0.033214       0.033233   0.262584
# APR MDC Description                     0.033214       0.033233   0.262584
# APR Severity of Illness Code            0.019723       0.019726   0.060162
# APR Severity of Illness Description     0.019723       0.019726   0.060162
# APR Risk of Mortality                   0.022688       0.022699   0.116747
# APR Medical Surgical Description        0.067803       0.068199   0.041737
# Payment Typology 1                      0.076152       0.076221   0.141611
# Payment Typology 2                      0.148217       0.148226   0.079753
# Payment Typology 3                      0.166058       0.166060   0.017229
# Emergency Department Indicator          0.149258       0.149331   0.123692
#
#                                      Zip Code - 3 digits    Gender      Race  \
# Health Service Area                             0.811583  0.000062  0.060777
# Hospital County                                 0.324564  0.000451  0.105596
# Facility Id                                     0.387115  0.006372  0.230153
# Facility Name                                   0.387116  0.006387  0.230155
# Age Group                                       0.005034  0.014630  0.014745
# Zip Code - 3 digits                             1.000000  0.000682  0.105736
# Gender                                          0.000682  1.000000  0.000095
# Race                                            0.105736  0.000095  1.000000
# Ethnicity                                       0.042755  0.000036  0.063863
# Type of Admission                               0.008003  0.007295  0.006529
# Patient Disposition                             0.002386  0.003619  0.005916
# CCS Diagnosis Code                              0.002163  0.071508  0.024855
# CCS Diagnosis Description                       0.002163  0.071508  0.024855
# CCS Procedure Code                              0.004100  0.069034  0.017552
# CCS Procedure Description                       0.004100  0.069034  0.017552
# APR DRG Code                                    0.002415  0.072463  0.025238
# APR DRG Description                             0.002415  0.072463  0.025238
# APR MDC Code                                    0.001604  0.061826  0.011239
# APR MDC Description                             0.001604  0.061826  0.011239
# APR Severity of Illness Code                    0.001974  0.002247  0.002438
# APR Severity of Illness Description             0.001974  0.002247  0.002438
# APR Risk of Mortality                           0.002320  0.003555  0.003952
# APR Medical Surgical Description                0.011194  0.001083  0.004539
# Payment Typology 1                              0.019477  0.002385  0.031317
# Payment Typology 2                              0.024970  0.000789  0.027001
# Payment Typology 3                              0.019536  0.000398  0.011208
# Emergency Department Indicator                  0.016722  0.004450  0.005195
#
#                                      Ethnicity  Type of Admission  ...  \
# Health Service Area                   0.021173           0.003078  ...
# Hospital County                       0.051130           0.015728  ...
# Facility Id                           0.163295           0.068559  ...
# Facility Name                         0.163296           0.068625  ...
# Age Group                             0.006575           0.163212  ...
# Zip Code - 3 digits                   0.042755           0.008003  ...
# Gender                                0.000036           0.007295  ...
# Race                                  0.063863           0.006529  ...
# Ethnicity                             1.000000           0.004394  ...
# Type of Admission                     0.004394           1.000000  ...
# Patient Disposition                   0.002753           0.012809  ...
# CCS Diagnosis Code                    0.008729           0.311655  ...
# CCS Diagnosis Description             0.008729           0.311655  ...
# CCS Procedure Code                    0.007818           0.229682  ...
# CCS Procedure Description             0.007818           0.229682  ...
# APR DRG Code                          0.008956           0.320753  ...
# APR DRG Description                   0.008956           0.320753  ...
# APR MDC Code                          0.005559           0.255451  ...
# APR MDC Description                   0.005559           0.255451  ...
# APR Severity of Illness Code          0.001417           0.046788  ...
# APR Severity of Illness Description   0.001417           0.046788  ...
# APR Risk of Mortality                 0.002245           0.044005  ...
# APR Medical Surgical Description      0.001726           0.220751  ...
# Payment Typology 1                    0.012986           0.025650  ...
# Payment Typology 2                    0.008692           0.011341  ...
# Payment Typology 3                    0.003564           0.003775  ...
# Emergency Department Indicator        0.002278           0.713928  ...
#
#                                      APR MDC Code  APR MDC Description  \
# Health Service Area                      0.002875             0.002875
# Hospital County                          0.003031             0.003031
# Facility Id                              0.033214             0.033214
# Facility Name                            0.033233             0.033233
# Age Group                                0.262584             0.262584
# Zip Code - 3 digits                      0.001604             0.001604
# Gender                                   0.061826             0.061826
# Race                                     0.011239             0.011239
# Ethnicity                                0.005559             0.005559
# Type of Admission                        0.255451             0.255451
# Patient Disposition                      0.018810             0.018810
# CCS Diagnosis Code                       0.823647             0.823647
# CCS Diagnosis Description                0.823647             0.823647
# CCS Procedure Code                       0.320866             0.320866
# CCS Procedure Description                0.320866             0.320866
# APR DRG Code                             0.986757             0.986757
# APR DRG Description                      0.986757             0.986757
# APR MDC Code                             1.000000             1.000000
# APR MDC Description                      1.000000             1.000000
# APR Severity of Illness Code             0.094812             0.094812
# APR Severity of Illness Description      0.094812             0.094812
# APR Risk of Mortality                    0.122993             0.122993
# APR Medical Surgical Description         0.227891             0.227891
# Payment Typology 1                       0.033033             0.033033
# Payment Typology 2                       0.012992             0.012992
# Payment Typology 3                       0.003699             0.003699
# Emergency Department Indicator           0.305978             0.305978
#
#                                      APR Severity of Illness Code  \
# Health Service Area                                      0.001004
# Hospital County                                          0.003008
# Facility Id                                              0.019723
# Facility Name                                            0.019726
# Age Group                                                0.060162
# Zip Code - 3 digits                                      0.001974
# Gender                                                   0.002247
# Race                                                     0.002438
# Ethnicity                                                0.001417
# Type of Admission                                        0.046788
# Patient Disposition                                      0.091816
# CCS Diagnosis Code                                       0.145568
# CCS Diagnosis Description                                0.145568
# CCS Procedure Code                                       0.119004
# CCS Procedure Description                                0.119004
# APR DRG Code                                             0.161771
# APR DRG Description                                      0.161771
# APR MDC Code                                             0.094812
# APR MDC Description                                      0.094812
# APR Severity of Illness Code                             1.000000
# APR Severity of Illness Description                      1.000000
# APR Risk of Mortality                                    0.328048
# APR Medical Surgical Description                         0.006912
# Payment Typology 1                                       0.040481
# Payment Typology 2                                       0.020684
# Payment Typology 3                                       0.006443
# Emergency Department Indicator                           0.087103
#
#                                      APR Severity of Illness Description  \
# Health Service Area                                             0.001004
# Hospital County                                                 0.003008
# Facility Id                                                     0.019723
# Facility Name                                                   0.019726
# Age Group                                                       0.060162
# Zip Code - 3 digits                                             0.001974
# Gender                                                          0.002247
# Race                                                            0.002438
# Ethnicity                                                       0.001417
# Type of Admission                                               0.046788
# Patient Disposition                                             0.091816
# CCS Diagnosis Code                                              0.145568
# CCS Diagnosis Description                                       0.145568
# CCS Procedure Code                                              0.119004
# CCS Procedure Description                                       0.119004
# APR DRG Code                                                    0.161771
# APR DRG Description                                             0.161771
# APR MDC Code                                                    0.094812
# APR MDC Description                                             0.094812
# APR Severity of Illness Code                                    1.000000
# APR Severity of Illness Description                             1.000000
# APR Risk of Mortality                                           0.328048
# APR Medical Surgical Description                                0.006912
# Payment Typology 1                                              0.040481
# Payment Typology 2                                              0.020684
# Payment Typology 3                                              0.006443
# Emergency Department Indicator                                  0.087103
#
#                                      APR Risk of Mortality  \
# Health Service Area                               0.001965
# Hospital County                                   0.003230
# Facility Id                                       0.022688
# Facility Name                                     0.022699
# Age Group                                         0.116747
# Zip Code - 3 digits                               0.002320
# Gender                                            0.003555
# Race                                              0.003952
# Ethnicity                                         0.002245
# Type of Admission                                 0.044005
# Patient Disposition                               0.125304
# CCS Diagnosis Code                                0.170195
# CCS Diagnosis Description                         0.170195
# CCS Procedure Code                                0.126258
# CCS Procedure Description                         0.126258
# APR DRG Code                                      0.186851
# APR DRG Description                               0.186851
# APR MDC Code                                      0.122993
# APR MDC Description                               0.122993
# APR Severity of Illness Code                      0.328048
# APR Severity of Illness Description               0.328048
# APR Risk of Mortality                             1.000000
# APR Medical Surgical Description                  0.005004
# Payment Typology 1                                0.085170
# Payment Typology 2                                0.044747
# Payment Typology 3                                0.012136
# Emergency Department Indicator                    0.107037
#
#                                      APR Medical Surgical Description  \
# Health Service Area                                          0.002636
# Hospital County                                              0.024265
# Facility Id                                                  0.067803
# Facility Name                                                0.068199
# Age Group                                                    0.041737
# Zip Code - 3 digits                                          0.011194
# Gender                                                       0.001083
# Race                                                         0.004539
# Ethnicity                                                    0.001726
# Type of Admission                                            0.220751
# Patient Disposition                                          0.025537
# CCS Diagnosis Code                                           0.446982
# CCS Diagnosis Description                                    0.446982
# CCS Procedure Code                                           0.835933
# CCS Procedure Description                                    0.835933
# APR DRG Code                                                 1.000000
# APR DRG Description                                          1.000000
# APR MDC Code                                                 0.227891
# APR MDC Description                                          0.227891
# APR Severity of Illness Code                                 0.006912
# APR Severity of Illness Description                          0.006912
# APR Risk of Mortality                                        0.005004
# APR Medical Surgical Description                             0.999997
# Payment Typology 1                                           0.019572
# Payment Typology 2                                           0.005316
# Payment Typology 3                                           0.002723
# Emergency Department Indicator                               0.066345
#
#                                      Payment Typology 1  Payment Typology 2  \
# Health Service Area                            0.010555            0.019451
# Hospital County                                0.026145            0.041796
# Facility Id                                    0.076152            0.148217
# Facility Name                                  0.076221            0.148226
# Age Group                                      0.141611            0.079753
# Zip Code - 3 digits                            0.019477            0.024970
# Gender                                         0.002385            0.000789
# Race                                           0.031317            0.027001
# Ethnicity                                      0.012986            0.008692
# Type of Admission                              0.025650            0.011341
# Patient Disposition                            0.049015            0.013419
# CCS Diagnosis Code                             0.046944            0.018243
# CCS Diagnosis Description                      0.046944            0.018243
# CCS Procedure Code                             0.030707            0.012750
# CCS Procedure Description                      0.030707            0.012750
# APR DRG Code                                   0.047282            0.018238
# APR DRG Description                            0.047282            0.018238
# APR MDC Code                                   0.033033            0.012992
# APR MDC Description                            0.033033            0.012992
# APR Severity of Illness Code                   0.040481            0.020684
# APR Severity of Illness Description            0.040481            0.020684
# APR Risk of Mortality                          0.085170            0.044747
# APR Medical Surgical Description               0.019572            0.005316
# Payment Typology 1                             1.000000            0.063005
# Payment Typology 2                             0.063005            1.000000
# Payment Typology 3                             0.026328            0.076674
# Emergency Department Indicator                 0.074585            0.032542
#
#                                      Payment Typology 3  \
# Health Service Area                            0.012117
# Hospital County                                0.033962
# Facility Id                                    0.166058
# Facility Name                                  0.166060
# Age Group                                      0.017229
# Zip Code - 3 digits                            0.019536
# Gender                                         0.000398
# Race                                           0.011208
# Ethnicity                                      0.003564
# Type of Admission                              0.003775
# Patient Disposition                            0.003799
# CCS Diagnosis Code                             0.006428
# CCS Diagnosis Description                      0.006428
# CCS Procedure Code                             0.005337
# CCS Procedure Description                      0.005337
# APR DRG Code                                   0.006464
# APR DRG Description                            0.006464
# APR MDC Code                                   0.003699
# APR MDC Description                            0.003699
# APR Severity of Illness Code                   0.006443
# APR Severity of Illness Description            0.006443
# APR Risk of Mortality                          0.012136
# APR Medical Surgical Description               0.002723
# Payment Typology 1                             0.026328
# Payment Typology 2                             0.076674
# Payment Typology 3                             1.000000
# Emergency Department Indicator                 0.013245
#
#                                      Emergency Department Indicator
# Health Service Area                                        0.004783
# Hospital County                                            0.044430
# Facility Id                                                0.149258
# Facility Name                                              0.149331
# Age Group                                                  0.123692
# Zip Code - 3 digits                                        0.016722
# Gender                                                     0.004450
# Race                                                       0.005195
# Ethnicity                                                  0.002278
# Type of Admission                                          0.713928
# Patient Disposition                                        0.037144
# CCS Diagnosis Code                                         0.440114
# CCS Diagnosis Description                                  0.440114
# CCS Procedure Code                                         0.348146
# CCS Procedure Description                                  0.348146
# APR DRG Code                                               0.482535
# APR DRG Description                                        0.482535
# APR MDC Code                                               0.305978
# APR MDC Description                                        0.305978
# APR Severity of Illness Code                               0.087103
# APR Severity of Illness Description                        0.087103
# APR Risk of Mortality                                      0.107037
# APR Medical Surgical Description                           0.066345
# Payment Typology 1                                         0.074585
# Payment Typology 2                                         0.032542
# Payment Typology 3                                         0.013245
# Emergency Department Indicator                             0.999997
#
# [27 rows x 27 columns]

# %%
X = data.drop(['Total Costs'],axis=1)
y = data['Total Costs']
from sklearn.linear_model import LassoLars
model = LassoLars(alpha=0.01,eps=1e-10).fit(X,y)

# %%
cos = [
       'APR DRG Code', 'APR MDC Code', 'APR Medical Surgical Description','APR Risk of Mortality', 'APR Severity of Illness Code', 
       'CCS Diagnosis Code', 'CCS Procedure Code',

       'Emergency Department Indicator','Health Service Area','Facility Name','Type of Admission',
       
       'Age Group','Ethnicity','Gender','Race', 'Patient Disposition',
       'Payment Typology 1', 'Payment Typology 2', 'Payment Typology 3',
       'Zip Code - 3 digits','Hospital County'
]
for col in cos:
    fig = plt.figure()
    fig.figsize = (5,5)
    ax = fig.add_subplot(1,1,1)
    plt.tight_layout()
    ax.set_title(col)
    data.plot(kind="scatter", x=col, y="Total Costs",ax = ax)

# %%
for col in cols:
    print(data[col].value_counts())

# %%
from sklearn.feature_selection import SelectKBest, mutual_info_regression
X = data.drop(["Total Costs"],axis=1)
y = data["Total Costs"]
X_cont = X.select_dtypes(include=["float64"])
X_dis = X.select_dtypes(exclude=["float64"])
X_dis_new = SelectKBest(mutual_info_regression,k=20).fit_transform(X_dis,y)
X_dis_new.shape

# %%
test_x_new = best_model.transform(test_x)
pred = model.predict(test_x)

from sklearn.metrics import mean_absolute_percentage_error
mean_absolute_percentage_error(test_y, pred)

# %%
from sklearn.preprocessing import PolynomialFeatures
poly = PolynomialFeatures(degree=3,interaction_only=True,include_bias=False)
xtrain_apr = data.get(['APR DRG Code', 'APR MDC Code','APR Severity of Illness Code', 'APR Risk of Mortality','APR Medical Surgical Description'])
xtrain_payment = data.get(['Payment Typology 1','Payment Typology 2', 'Payment Typology 3'])
xtrain_ccs = data.get(['CCS Diagnosis Code','CCS Procedure Code'])
